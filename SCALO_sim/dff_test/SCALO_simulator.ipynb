# %% [markdown]
# # Helpful resources:
#
# - cocotb docs: https://docs.cocotb.org/en/stable/

# %% [markdown]
# # Environment Setup

# %%
# !pip install cocotb

# %%
# sanity check
# !cocotb-config --version
# Out:
# 1.8.1

# %%
# !sudo apt-get install -y iverilog
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# iverilog is already the newest version (11.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# # Running a basic sim

# %%
# !make SIM=icarus
# Out:
# rm -f results.xml
# make -f Makefile results.xml
# make[1]: Entering directory '/content'
# rm -f results.xml
# MODULE=test_dff TESTCASE= TOPLEVEL=dff TOPLEVEL_LANG=verilog \
#          /usr/bin/vvp -M /usr/local/lib/python3.10/dist-packages/cocotb/libs -m libcocotbvpi_icarus   sim_build/sim.vvp
#      -.--ns INFO     gpi                                ..mbed/gpi_embed.cpp:76   in set_program_name_in_venv        Did not detect Python virtual environment. Using system-wide Python interpreter
#      -.--ns INFO     gpi                                ../gpi/GpiCommon.cpp:101  in gpi_print_registered_impl       VPI registered
#      0.00ns INFO     cocotb                             Running on Icarus Verilog version 11.0 (stable)
#      0.00ns INFO     cocotb                             Running tests with cocotb v1.8.1 from /usr/local/lib/python3.10/dist-packages/cocotb
#      0.00ns INFO     cocotb                             Seeding Python random module with 1719071878
# ...

# %%
# !ls
# Out:
# dff.sv	drive  Makefile  __pycache__  results.xml  sample_data	sim_build  test_dff.py

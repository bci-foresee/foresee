# %% [markdown]
# # Helpful resources:
#
# - cocotb docs: https://docs.cocotb.org/en/stable/

# %% [markdown]
# ## Now working w github codespaces :)

# %% [markdown]
# # Environment Setup

# %%
# !pip install cocotb
# Out:
# Collecting cocotb
#   Downloading cocotb-1.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting find-libpython (from cocotb)
#   Downloading find_libpython-0.4.0-py3-none-any.whl.metadata (2.8 kB)
# Downloading cocotb-1.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 35.5 MB/s eta 0:00:0000:0100:01
# Downloading find_libpython-0.4.0-py3-none-any.whl (8.7 kB)
# Installing collected packages: find-libpython, cocotb
# Successfully installed cocotb-1.8.1 find-libpython-0.4.0

# %%
# sanity check
# !cocotb-config --version
# Out:
# 1.8.1

# %% [markdown]
# Run this in the terminal:
#
# ```sh
# sudo apt update
# sudo apt install -y iverilog
# ```
#
# sanity check:
# ```sh
# iverilog -v
# ```

# %% [markdown]
# # Running a basic sim

# %%
# !make SIM=icarus
# Out:
# rm -f results.xml
# make -f Makefile results.xml
# make[1]: Entering directory '/workspaces/aloha-verilog/SCALO_sim/dff_test'
# mkdir -p sim_build
# /usr/bin/iverilog -o sim_build/sim.vvp -D COCOTB_SIM=1 -s dff -f sim_build/cmds.f -g2012   /workspaces/aloha-verilog/SCALO_sim/dff_test/dff.sv
# rm -f results.xml
# MODULE=test_dff TESTCASE= TOPLEVEL=dff TOPLEVEL_LANG=verilog \
#          /usr/bin/vvp -M /workspaces/aloha-verilog/.conda/lib/python3.11/site-packages/cocotb/libs -m libcocotbvpi_icarus   sim_build/sim.vvp
#      -.--ns INFO     gpi                                ..mbed/gpi_embed.cpp:76   in set_program_name_in_venv        Did not detect Python virtual environment. Using system-wide Python interpreter
#      -.--ns INFO     gpi                                ../gpi/GpiCommon.cpp:101  in gpi_print_registered_impl       VPI registered
#      0.00ns INFO     cocotb                             Running on Icarus Verilog version 10.3 (stable)
#      0.00ns INFO     cocotb                             Running tests with cocotb v1.8.1 from /workspaces/aloha-verilog/.conda/lib/python3.11/site-packages/cocotb
#      0.00ns INFO     cocotb                             Seeding Python random module with 1719072776
#      0.00ns INFO     cocotb.regression                  pytest not found, install it to enable better AssertionError messages
#      0.00ns INFO     cocotb.regression                  Found test test_dff.dff_simple_test
#      0.00ns INFO     cocotb.regression                  running dff_simple_test (1/1)
#                                                           Test that d propagates to q
# 115001.00ns INFO     cocotb.regression                  dff_simple_test passed
# 115001.00ns INFO     cocotb.regression                  **************************************************************************************
#                                                         ** TEST                          STATUS  SIM TIME (ns)  REAL TIME (s)  RATIO (ns/s) **
#                                                         **************************************************************************************
#                                                         ** test_dff.dff_simple_test       PASS      115001.00           0.00   64910396.22  **
#                                                         **************************************************************************************
#                                                         ** TESTS=1 PASS=1 FAIL=0 SKIP=0             115001.00           0.01   18708030.65  **
#                                                         **************************************************************************************
#
# make[1]: Leaving directory '/workspaces/aloha-verilog/SCALO_sim/dff_test'
